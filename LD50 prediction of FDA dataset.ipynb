# %%
import os
import pandas as pd
import numpy as np

import rdkit
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Avalon import pyAvalonTools
from rdkit.Chem import Draw
from rdkit.Chem import PandasTools
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Descriptors

from models.mol2vec.features import mol2alt_sentence, mol2sentence, MolSentence, DfVec, sentences2vec
from models.mol2vec.helpers import depict_identifier, mol_to_svg
from gensim.models import word2vec

import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from math import sqrt
from statistics import mean, stdev
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import KFold

# %%
class CustomModel_2(nn.Module):
    def __init__(self):
        super(CustomModel_2, self).__init__()
        self.fc1 = nn.Linear(input_dim, 1500)
        self.fc2 = nn.Linear(1500, 500)
        self.fc3 = nn.Linear(500, 100)
        self.fc4 = nn.Linear(100, 59)
        
        
    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = torch.relu(self.fc3(x))
        x = self.fc4(x)
        
        return x
    
def toxic_label(value):
    if value >= 5000: 
        return 'Safe_chemicals'
    elif value >= 500:
        return 'Slightly_toxic'
    elif value >= 50:
        return 'Moderately_toxic'
    else:
        return 'Highest_toxic'

def toxic_label2(value):
    if value >= 2000: 
        return 'Safe_chemicals'
    else:
        return 'Toxic_chemicals'

# %%
# 경로 설정
path = os.getcwd()
model_path = path + '/models/'
if not os.path.exists(model_path):
    os.makedirs(model_path)
data_path = path + '/data/'
if not os.path.exists(data_path):
    os.makedirs(data_path)
    
# device = torch.device('cuda:3') if torch.cuda.is_available() else torch.device('cpu')
device = torch.device('cpu')

# %%
print('Generate Molwt column')
# reverse standardization을 위한 MolWt 추출
data = pd.read_csv("/home/psy/LD50/Toxicity_prediction/data/FDA_smiles_jy.csv")
data = data.iloc[:,0:2]
smiles_list = data['canonical smiles'].values # SMILES 부분민 추출
mol = [ Chem.MolFromSmiles(smiles) for smiles in smiles_list]
molecular_weight = [Descriptors.MolWt(mols) for mols in mol]
data['MolWt'] = molecular_weight
print('Done')
# Out:
# Generate Molwt column
# Done
# [14:19:47] WARNING: not removing hydrogen atom without neighbors
# [14:19:47] WARNING: not removing hydrogen atom without neighbors

# %%
print('Generate Avalon_fp')
# SMILES 문자열을 Molecule 객체로 변환하고 Avalon fingerprint 생성
avalon_fps = []
for smiles in smiles_list: # 각각의 smile에 해당하는 avalon_fp 를 얻기 위한 for문
    mol = Chem.MolFromSmiles(smiles) # smiles를 molecule로 변환
    if mol is not None:
        avalon_fp = rdkit.Avalon.pyAvalonTools.GetAvalonFP(mol, nBits=1024) # molecule 을 avalon_fp로 변환
        binary_avalon_fp = avalon_fp.ToList() # 0,1 로 구성된 1024bit로 표현
        avalon_fps.append(binary_avalon_fp)
    else:
        print(f"Failed to generate Avalon fingerprint for SMILES: {smiles}") # SMILES 정보가 database에 존재하지 않을 시 error
avalon_fps = np.array(avalon_fps)

# avalon_fp의 각 col name을 Avalon_i 로 표현
col_list = [] 
for i in range(1024):
    col_names = f'Avalon_{i}'
    col_list.append(col_names)
    
avalon_bits = pd.DataFrame(avalon_fps)
avalon_bits.columns = col_list
print('Done')
# Out:
# Generate Avalon_fp
# [14:19:53] WARNING: not removing hydrogen atom without neighbors
# [14:19:53] WARNING: not removing hydrogen atom without neighbors
# Done

# %%
print('Generate mol2vec embedding vector')
# Unseen data의 mo2lvec embedding vector 생성
mol2vec_df = data.iloc[:,0:2] # ID와 smiles만 추출

mol = [Chem.MolFromSmiles(x) for x in smiles_list]
#Draw.MolsToGridImage(mol, molsPerRow=5, useSVG=False) # 시각화
mol2vec_df['ROMol'] = mol

# molecule 별로 sentence 생성
mol2vec_df['sentence'] = mol2vec_df.apply(lambda x: MolSentence(mol2alt_sentence(x['ROMol'], 1)), axis=1)

# pretrained mol2vec model 불러오기
model = word2vec.Word2Vec.load(model_path + 'mol2vec/mol2vec_300dim.pkl')

# mol2vec embedding vector 생성
mol2vec_df['mol2vec'] = [DfVec(x) for x in sentences2vec(mol2vec_df['sentence'], model, unseen='UNK')]

# mol2vec embedding vector 저장
mol2vec_emb = np.array([x.vec for x in mol2vec_df['mol2vec']])

col_list = [] 
for i in range(300):
    col_names = f'Mol2vec_{i}'
    col_list.append(col_names)
    
Mol2vec = pd.DataFrame(mol2vec_emb)
Mol2vec.columns = col_list
print('Done')
# Out:
# Generate mol2vec embedding vector
# [14:19:55] WARNING: not removing hydrogen atom without neighbors
# [14:19:56] WARNING: not removing hydrogen atom without neighbors
# Done

# %%
print('Prediction start')
# prediction 결과를 reverse standardization 하여 class_assign을 하고 toxicity count와 percantage, score를 구하는 코드
# remove_col = data.columns[2:1085]
# data = data.drop(columns=remove_col)

test_set = pd.concat([data,avalon_bits,Mol2vec],axis=1)
X_test = test_set.iloc[:,3:].values
# X_test_tensor = torch.tensor(X_test, dtype=torch.float32).to(device)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
input_dim = X_test.shape[1]

# model = CustomModel_2().to(device)
model = CustomModel_2()
model.load_state_dict(torch.load(model_path + f'Best_model_fold_1', map_location='cpu'))

model.eval()
with torch.no_grad():
#     y_pred = model(X_test_tensor).cpu().numpy()
    y_pred = model(X_test_tensor).numpy()
print('Done')
# Out:
# Prediction start
# Done

# %% [markdown]
# # Classification assign1

# %%
print('Make result file format')
task_list = np.load(data_path + "task_list.npy")
pred = pd.DataFrame(y_pred)
pred.columns = task_list
pred['molwt'] = data['MolWt'].values

for i in range(len(pred)):
    reverse_standardization = (1/10**(pred.iloc[i,0:59]))*pred.iloc[i,59]*10**(3)
    pred.iloc[i,0:59] = reverse_standardization
    
pred_label = pred.iloc[:,0:-1]
pred_label = pred_label.applymap(toxic_label)
pred_label = pd.concat([data,pred_label],axis=1)
count_label = pred_label.iloc[:,3:].T

pred_label['Safe_chemicals'] = 0
pred_label['Slightly_toxicity'] = 0
pred_label['Moderately_toxicity'] = 0
pred_label['Highest_toxicity'] = 0

count_list = []
for i in range(len(count_label.columns)):
    dict = count_label.iloc[:,i].value_counts().to_dict()
    count_list.append(dict)

for i in range(len(count_label.columns)):
    try:
        pred_label.loc[i,'Safe_chemicals'] = count_list[i]['Safe_chemicals']
    except KeyError:
        pred_label.loc[i,'Safe_chemicals'] = 0
    try:
        pred_label.loc[i,'Slightly_toxicity'] = count_list[i]['Slightly_toxic']
    except KeyError:
        pred_label.loc[i,'Slightly_toxicity'] = 0
    try:
        pred_label.loc[i,'Moderately_toxicity'] = count_list[i]['Moderately_toxic']
    except KeyError:
        pred_label.loc[i,'Moderately_toxicity'] = 0
    try:
        pred_label.loc[i,'Highest_toxicity'] = count_list[i]['Highest_toxic']
    except KeyError:
        pred_label.loc[i,'Highest_toxicity'] = 0
        
toxic_count = pred_label.iloc[:,-4:].values
toxic_percentage = np.round((toxic_count/59)*100,2)

col_names = ['Safe_chemicals_per','Slightly_toxicity_per','Moderately_toxicity_per','Highest_toxicity_per']
toxic_per = pd.DataFrame(toxic_percentage,columns = col_names)

results = pd.concat([pred_label.iloc[:,0:2],pred_label.iloc[:,-4:],toxic_per],axis=1)
results['toxic_score'] = np.round((results['Safe_chemicals']*0 + results['Slightly_toxicity']*3.33 + results['Moderately_toxicity']*6.66 + results['Highest_toxicity']*10)/59,2)
results['std'] = np.round(results.iloc[:,2:6].std(axis=1),2)

results.to_csv(path+'/Results/LD50_prediction_of_FDA.csv',index=False)
print('Done')
# results
# Out:
# Make result file format
# Done

# %% [markdown]
# # Classification assign2

# %%
print('Make result file format')
task_list = np.load(data_path + "task_list.npy")
pred = pd.DataFrame(y_pred)
pred.columns = task_list
pred['molwt'] = data['MolWt'].values

for i in range(len(pred)):
    reverse_standardization = (1/10**(pred.iloc[i,0:59]))*pred.iloc[i,59]*10**(3)
    pred.iloc[i,0:59] = reverse_standardization
    
pred_label = pred.iloc[:,0:-1]
pred_label = pred_label.applymap(toxic_label2)
pred_label = pd.concat([data,pred_label],axis=1)
count_label = pred_label.iloc[:,3:].T

pred_label['Safe_chemicals'] = 0
pred_label['Toxic_chemicals'] = 0

count_list = []
for i in range(len(count_label.columns)):
    dict = count_label.iloc[:,i].value_counts().to_dict()
    count_list.append(dict)

for i in range(len(count_label.columns)):
    try:
        pred_label.loc[i,'Safe_chemicals'] = count_list[i]['Safe_chemicals']
    except KeyError:
        pred_label.loc[i,'Safe_chemicals'] = 0
    try:
        pred_label.loc[i,'Toxic_chemicals'] = count_list[i]['Toxic_chemicals']
    except KeyError:
        pred_label.loc[i,'Toxic_chemicals'] = 0

        
toxic_count = pred_label.iloc[:,-2:].values
toxic_percentage = np.round((toxic_count/59)*100,2)

col_names = ['Safe_chemicals_per','Toxic_chemicals_per']
toxic_per = pd.DataFrame(toxic_percentage,columns = col_names)

results = pd.concat([pred_label.iloc[:,0:2],pred_label.iloc[:,-2:],toxic_per],axis=1)
# results['toxic_score'] = np.round((results['Safe_chemicals']*0 + results['Slightly_toxicity']*3.33 + results['Moderately_toxicity']*6.66 + results['Highest_toxicity']*10)/59,2)
# results['std'] = np.round(results.iloc[:,2:6].std(axis=1),2)

results.to_csv(path+'/Results/LD50_prediction_of_FDA2.csv',index=False)
print('Done')
# results
# Out:
# Make result file format
# Done

# %%
results
# Out:
#                             drug_name  \
# 0                        ROSUVASTATIN
# 1     ATORVASTATIN CALCIUM TRIHYDRATE
# 2            TAPENTADOL HYDROCHLORIDE
# 3                       BUPRENORPHINE
# 4                           TOLCAPONE
# ...                               ...
# 1372                       TELAPREVIR
# 1373                      COBIMETINIB
# 1374                     DROSPIRENONE
# 1375                         ABACAVIR
# 1376                    NORTRIPTYLINE
#
#                                        canonical smiles  Safe_chemicals  \
# 0     CC(C)C1=NC(=NC(=C1C=CC(CC(CC(=O)O)O)O)C2=CC=C(...              58
# 1     CC(C)C1=C(C(=C(N1CCC(CC(CC(=O)[O-])O)O)C2=CC=C...              44
# 2                      CCC(C1=CC(=CC=C1)O)C(C)CN(C)C.Cl              58
# 3     CC(C)(C)C(C)(C1CC23CCC1(C4C25CCN(C3CC6=C5C(=C(...              57
# 4     CC1=CC=C(C=C1)C(=O)C2=CC(=C(C(=C2)O)O)[N+](=O)...              59
# ...                                                 ...             ...
# 1372  CCCC(C(=O)C(=O)NC1CC1)NC(=O)C2C3CCCC3CN2C(=O)C...              55
# 1373  C1CCNC(C1)C2(CN(C2)C(=O)C3=C(C(=C(C=C3)F)F)NC4...              56
# 1374  CC12CCC(=O)C=C1C3CC3C4C2CCC5(C4C6CC6C57CCC(=O)...              58
# 1375         C1CC1NC2=C3C(=NC(=N2)N)N(C=N3)C4CC(C=C4)CO              56
# 1376                  CNCCC=C1C2=CC=CC=C2CCC3=CC=CC=C31              59
#
#       Toxic_chemicals  Safe_chemicals_per  Toxic_chemicals_per
# 0                   1               98.31                 1.69
# 1                  15               74.58                25.42
# 2                   1               98.31                 1.69
# 3                   2               96.61                 3.39
# 4                   0              100.00                 0.00
# ...               ...                 ...                  ...
# 1372                4               93.22                 6.78
# 1373                3               94.92                 5.08
# 1374                1               98.31                 1.69
# 1375                3               94.92                 5.08
# 1376                0              100.00                 0.00
#
# [1377 rows x 6 columns]

# %%
pred_label
# Out:
#                             drug_name  \
# 0                        ROSUVASTATIN
# 1     ATORVASTATIN CALCIUM TRIHYDRATE
# 2            TAPENTADOL HYDROCHLORIDE
# 3                       BUPRENORPHINE
# 4                           TOLCAPONE
# ...                               ...
# 1372                       TELAPREVIR
# 1373                      COBIMETINIB
# 1374                     DROSPIRENONE
# 1375                         ABACAVIR
# 1376                    NORTRIPTYLINE
#
#                                        canonical smiles     MolWt  \
# 0     CC(C)C1=NC(=NC(=C1C=CC(CC(CC(=O)O)O)O)C2=CC=C(...   481.546
# 1     CC(C)C1=C(C(=C(N1CCC(CC(CC(=O)[O-])O)O)C2=CC=C...  1209.407
# 2                      CCC(C1=CC(=CC=C1)O)C(C)CN(C)C.Cl   257.805
# 3     CC(C)(C)C(C)(C1CC23CCC1(C4C25CCN(C3CC6=C5C(=C(...   467.650
# 4     CC1=CC=C(C=C1)C(=O)C2=CC(=C(C(=C2)O)O)[N+](=O)...   273.244
# ...                                                 ...       ...
# 1372  CCCC(C(=O)C(=O)NC1CC1)NC(=O)C2C3CCCC3CN2C(=O)C...   679.863
# 1373  C1CCNC(C1)C2(CN(C2)C(=O)C3=C(C(=C(C=C3)F)F)NC4...   531.316
# 1374  CC12CCC(=O)C=C1C3CC3C4C2CCC5(C4C6CC6C57CCC(=O)...   366.501
# 1375         C1CC1NC2=C3C(=NC(=N2)N)N(C=N3)C4CC(C=C4)CO   286.339
# 1376                  CNCCC=C1C2=CC=CC=C2CCC3=CC=CC=C31   263.384
#
#      mouse_intraperitoneal_LD50  \
# 0                         Toxic
# 1                         Toxic
# 2                         Toxic
# 3                         Toxic
# 4                         Toxic
# ...                         ...
# 1372                      Toxic
# 1373                      Toxic
# 1374                      Toxic
# 1375                      Toxic
# 1376                      Toxic
#
#      mammal (species unspecified)_intraperitoneal_LD50  \
# 0                                                Toxic
# 1                                                Toxic
# 2                                                Toxic
# 3                                                Toxic
# 4                                                Toxic
# ...                                                ...
# 1372                                             Toxic
# 1373                                             Toxic
# 1374                                             Toxic
# 1375                                             Toxic
# 1376                                             Toxic
#
#      guinea pig_intraperitoneal_LD50 rat_intraperitoneal_LD50  \
# 0                              Toxic                    Toxic
# 1                              Toxic                    Toxic
# 2                              Toxic                    Toxic
# 3                              Toxic                    Toxic
# 4                              Toxic                    Toxic
# ...                              ...                      ...
# 1372                           Toxic                    Toxic
# 1373                           Toxic                    Toxic
# 1374                           Toxic                    Toxic
# 1375                           Toxic                    Toxic
# 1376                           Toxic                    Toxic
#
#      rabbit_intraperitoneal_LD50 mouse_intraperitoneal_LDLo  \
# 0                          Toxic                      Toxic
# 1                          Toxic                      Toxic
# 2                          Toxic                      Toxic
# 3                          Toxic                      Toxic
# 4                          Toxic                      Toxic
# ...                          ...                        ...
# 1372                       Toxic                      Toxic
# 1373                       Toxic                      Toxic
# 1374                       Toxic                      Toxic
# 1375                       Toxic                      Toxic
# 1376                       Toxic                      Toxic
#
#      rat_intraperitoneal_LDLo  ... guinea pig_subcutaneous_LDLo  \
# 0                       Toxic  ...                        Toxic
# 1                       Toxic  ...                        Toxic
# 2                       Toxic  ...                        Toxic
# 3                       Toxic  ...                        Toxic
# 4                       Toxic  ...                        Toxic
# ...                       ...  ...                          ...
# 1372                    Toxic  ...                        Toxic
# 1373                    Toxic  ...                        Toxic
# 1374                    Toxic  ...                        Toxic
# 1375                    Toxic  ...                        Toxic
# 1376                    Toxic  ...                        Toxic
#
#      rat_subcutaneous_LDLo rabbit_subcutaneous_LDLo frog_subcutaneous_LDLo  \
# 0                    Toxic                    Toxic                  Toxic
# 1                    Toxic                    Toxic                  Toxic
# 2                    Toxic                    Toxic                  Toxic
# 3                    Toxic                    Toxic                  Toxic
# 4                    Toxic                    Toxic                  Toxic
# ...                    ...                      ...                    ...
# 1372                 Toxic                    Toxic                  Toxic
# 1373                 Toxic                    Toxic                  Toxic
# 1374                 Toxic                    Toxic                  Toxic
# 1375                 Toxic                    Toxic                  Toxic
# 1376                 Toxic                    Toxic                  Toxic
#
#      mouse_intramuscular_LD50 rat_intramuscular_LD50 mouse_parenteral_LD50  \
# 0                       Toxic                  Toxic                 Toxic
# 1                       Toxic                  Toxic                 Toxic
# 2                       Toxic                  Toxic                 Toxic
# 3                       Toxic                  Toxic                 Toxic
# 4                       Toxic                  Toxic                 Toxic
# ...                       ...                    ...                   ...
# 1372                    Toxic                  Toxic                 Toxic
# 1373                    Toxic                  Toxic                 Toxic
# 1374                    Toxic                  Toxic                 Toxic
# 1375                    Toxic                  Toxic                 Toxic
# 1376                    Toxic                  Toxic                 Toxic
#
#      Safe_chemicals Toxicity_chemicals Toxic_chemicals
# 0                 0                  0             0.0
# 1                11                  0             0.0
# 2                 1                  0             0.0
# 3                 2                  0             0.0
# 4                 0                  0             0.0
# ...             ...                ...             ...
# 1372              3                  0             0.0
# 1373              3                  0             0.0
# 1374              0                  0             0.0
# 1375              2                  0             0.0
# 1376              0                  0             0.0
#
# [1377 rows x 65 columns]

# %%
pred_label['Safe_chemicals'] = 0
pred_label['Toxicity_chemicals'] = 0

count_list = []
for i in range(len(count_label.columns)):
    dict = count_label.iloc[:,i].value_counts().to_dict()
    count_list.append(dict)

for i in range(len(count_label.columns)):
    try:
        pred_label.loc[i,'Safe_chemicals'] = count_list[i]['Safe_chemicals']
    except KeyError:
        pred_label.loc[i,'Safe_chemicals'] = 0
    try:
        pred_label.loc[i,'Toxic_chemicals'] = count_list[i]['Toxic_chemicals']
    except KeyError:
        pred_label.loc[i,'Toxic_chemicals'] = 0

# %%
pred_label = pd.concat([data,pred_label],axis=1)
count_label = pred_label.iloc[:,3:].T

# %%
count_label = pred_label.iloc[:,3:].T

# %%
count_label
# Out:
#                                                     0               1     \
# mouse_intraperitoneal_LD50                         Toxic           Toxic
# mammal (species unspecified)_intraperitoneal_LD50  Toxic           Toxic
# guinea pig_intraperitoneal_LD50                    Toxic           Toxic
# rat_intraperitoneal_LD50                           Toxic           Toxic
# rabbit_intraperitoneal_LD50                        Toxic           Toxic
# mouse_intraperitoneal_LDLo                         Toxic           Toxic
# rat_intraperitoneal_LDLo                           Toxic           Toxic
# mouse_intravenous_LD50                             Toxic           Toxic
# guinea pig_intravenous_LD50                        Toxic  Safe_chemicals
# rat_intravenous_LD50                               Toxic  Safe_chemicals
# rabbit_intravenous_LD50                            Toxic  Safe_chemicals
# dog_intravenous_LD50                               Toxic  Safe_chemicals
# cat_intravenous_LD50                               Toxic  Safe_chemicals
# mouse_intravenous_LDLo                             Toxic           Toxic
# guinea pig_intravenous_LDLo                        Toxic           Toxic
# rat_intravenous_LDLo                               Toxic  Safe_chemicals
# rabbit_intravenous_LDLo                            Toxic           Toxic
# dog_intravenous_LDLo                               Toxic  Safe_chemicals
# cat_intravenous_LDLo                               Toxic  Safe_chemicals
# mouse_oral_LD50                                    Toxic           Toxic
# mammal (species unspecified)_oral_LD50             Toxic           Toxic
# guinea pig_oral_LD50                               Toxic           Toxic
# rat_oral_LD50                                      Toxic           Toxic
# rabbit_oral_LD50                                   Toxic           Toxic
# dog_oral_LD50                                      Toxic           Toxic
# cat_oral_LD50                                      Toxic           Toxic
# bird - wild_oral_LD50                              Toxic           Toxic
# quail_oral_LD50                                    Toxic           Toxic
# duck_oral_LD50                                     Toxic           Toxic
# chicken_oral_LD50                                  Toxic           Toxic
# mouse_oral_LDLo                                    Toxic           Toxic
# rat_oral_LDLo                                      Toxic           Toxic
# rabbit_oral_LDLo                                   Toxic           Toxic
# dog_oral_LDLo                                      Toxic           Toxic
# cat_oral_LDLo                                      Toxic           Toxic
# man_oral_TDLo                                      Toxic  Safe_chemicals
# women_oral_TDLo                                    Toxic  Safe_chemicals
# human_oral_TDLo                                    Toxic  Safe_chemicals
# mouse_unreported_LD50                              Toxic           Toxic
# mammal (species unspecified)_unreported_LD50       Toxic           Toxic
# rat_unreported_LD50                                Toxic           Toxic
# mouse_skin_LD50                                    Toxic           Toxic
# guinea pig_skin_LD50                               Toxic           Toxic
# rat_skin_LD50                                      Toxic           Toxic
# rabbit_skin_LD50                                   Toxic           Toxic
# rabbit_skin_LDLo                                   Toxic           Toxic
# mouse_subcutaneous_LD50                            Toxic           Toxic
# mammal (species unspecified)_subcutaneous_LD50     Toxic           Toxic
# guinea pig_subcutaneous_LD50                       Toxic           Toxic
# rat_subcutaneous_LD50                              Toxic           Toxic
# rabbit_subcutaneous_LD50                           Toxic           Toxic
# mouse_subcutaneous_LDLo                            Toxic           Toxic
# guinea pig_subcutaneous_LDLo                       Toxic           Toxic
# rat_subcutaneous_LDLo                              Toxic           Toxic
# rabbit_subcutaneous_LDLo                           Toxic           Toxic
# frog_subcutaneous_LDLo                             Toxic           Toxic
# mouse_intramuscular_LD50                           Toxic           Toxic
# rat_intramuscular_LD50                             Toxic           Toxic
# mouse_parenteral_LD50                              Toxic           Toxic
#
#                                                              2     \
# mouse_intraperitoneal_LD50                                  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic
# guinea pig_intraperitoneal_LD50                             Toxic
# rat_intraperitoneal_LD50                                    Toxic
# rabbit_intraperitoneal_LD50                                 Toxic
# mouse_intraperitoneal_LDLo                                  Toxic
# rat_intraperitoneal_LDLo                                    Toxic
# mouse_intravenous_LD50                                      Toxic
# guinea pig_intravenous_LD50                                 Toxic
# rat_intravenous_LD50                                        Toxic
# rabbit_intravenous_LD50                                     Toxic
# dog_intravenous_LD50                                        Toxic
# cat_intravenous_LD50                                        Toxic
# mouse_intravenous_LDLo                                      Toxic
# guinea pig_intravenous_LDLo                                 Toxic
# rat_intravenous_LDLo                                        Toxic
# rabbit_intravenous_LDLo                                     Toxic
# dog_intravenous_LDLo                                        Toxic
# cat_intravenous_LDLo                                        Toxic
# mouse_oral_LD50                                             Toxic
# mammal (species unspecified)_oral_LD50                      Toxic
# guinea pig_oral_LD50                                        Toxic
# rat_oral_LD50                                               Toxic
# rabbit_oral_LD50                                            Toxic
# dog_oral_LD50                                               Toxic
# cat_oral_LD50                                               Toxic
# bird - wild_oral_LD50                                       Toxic
# quail_oral_LD50                                             Toxic
# duck_oral_LD50                                              Toxic
# chicken_oral_LD50                                           Toxic
# mouse_oral_LDLo                                             Toxic
# rat_oral_LDLo                                               Toxic
# rabbit_oral_LDLo                                            Toxic
# dog_oral_LDLo                                               Toxic
# cat_oral_LDLo                                               Toxic
# man_oral_TDLo                                               Toxic
# women_oral_TDLo                                             Toxic
# human_oral_TDLo                                    Safe_chemicals
# mouse_unreported_LD50                                       Toxic
# mammal (species unspecified)_unreported_LD50                Toxic
# rat_unreported_LD50                                         Toxic
# mouse_skin_LD50                                             Toxic
# guinea pig_skin_LD50                                        Toxic
# rat_skin_LD50                                               Toxic
# rabbit_skin_LD50                                            Toxic
# rabbit_skin_LDLo                                            Toxic
# mouse_subcutaneous_LD50                                     Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic
# guinea pig_subcutaneous_LD50                                Toxic
# rat_subcutaneous_LD50                                       Toxic
# rabbit_subcutaneous_LD50                                    Toxic
# mouse_subcutaneous_LDLo                                     Toxic
# guinea pig_subcutaneous_LDLo                                Toxic
# rat_subcutaneous_LDLo                                       Toxic
# rabbit_subcutaneous_LDLo                                    Toxic
# frog_subcutaneous_LDLo                                      Toxic
# mouse_intramuscular_LD50                                    Toxic
# rat_intramuscular_LD50                                      Toxic
# mouse_parenteral_LD50                                       Toxic
#
#                                                              3      4     \
# mouse_intraperitoneal_LD50                                  Toxic  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic  Toxic
# guinea pig_intraperitoneal_LD50                             Toxic  Toxic
# rat_intraperitoneal_LD50                                    Toxic  Toxic
# rabbit_intraperitoneal_LD50                                 Toxic  Toxic
# mouse_intraperitoneal_LDLo                                  Toxic  Toxic
# rat_intraperitoneal_LDLo                                    Toxic  Toxic
# mouse_intravenous_LD50                                      Toxic  Toxic
# guinea pig_intravenous_LD50                                 Toxic  Toxic
# rat_intravenous_LD50                                        Toxic  Toxic
# rabbit_intravenous_LD50                                     Toxic  Toxic
# dog_intravenous_LD50                                        Toxic  Toxic
# cat_intravenous_LD50                                        Toxic  Toxic
# mouse_intravenous_LDLo                                      Toxic  Toxic
# guinea pig_intravenous_LDLo                                 Toxic  Toxic
# rat_intravenous_LDLo                                        Toxic  Toxic
# rabbit_intravenous_LDLo                                     Toxic  Toxic
# dog_intravenous_LDLo                                        Toxic  Toxic
# cat_intravenous_LDLo                                        Toxic  Toxic
# mouse_oral_LD50                                             Toxic  Toxic
# mammal (species unspecified)_oral_LD50                      Toxic  Toxic
# guinea pig_oral_LD50                                        Toxic  Toxic
# rat_oral_LD50                                               Toxic  Toxic
# rabbit_oral_LD50                                            Toxic  Toxic
# dog_oral_LD50                                               Toxic  Toxic
# cat_oral_LD50                                               Toxic  Toxic
# bird - wild_oral_LD50                                       Toxic  Toxic
# quail_oral_LD50                                             Toxic  Toxic
# duck_oral_LD50                                              Toxic  Toxic
# chicken_oral_LD50                                           Toxic  Toxic
# mouse_oral_LDLo                                             Toxic  Toxic
# rat_oral_LDLo                                               Toxic  Toxic
# rabbit_oral_LDLo                                            Toxic  Toxic
# dog_oral_LDLo                                               Toxic  Toxic
# cat_oral_LDLo                                               Toxic  Toxic
# man_oral_TDLo                                      Safe_chemicals  Toxic
# women_oral_TDLo                                             Toxic  Toxic
# human_oral_TDLo                                    Safe_chemicals  Toxic
# mouse_unreported_LD50                                       Toxic  Toxic
# mammal (species unspecified)_unreported_LD50                Toxic  Toxic
# rat_unreported_LD50                                         Toxic  Toxic
# mouse_skin_LD50                                             Toxic  Toxic
# guinea pig_skin_LD50                                        Toxic  Toxic
# rat_skin_LD50                                               Toxic  Toxic
# rabbit_skin_LD50                                            Toxic  Toxic
# rabbit_skin_LDLo                                            Toxic  Toxic
# mouse_subcutaneous_LD50                                     Toxic  Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic  Toxic
# guinea pig_subcutaneous_LD50                                Toxic  Toxic
# rat_subcutaneous_LD50                                       Toxic  Toxic
# rabbit_subcutaneous_LD50                                    Toxic  Toxic
# mouse_subcutaneous_LDLo                                     Toxic  Toxic
# guinea pig_subcutaneous_LDLo                                Toxic  Toxic
# rat_subcutaneous_LDLo                                       Toxic  Toxic
# rabbit_subcutaneous_LDLo                                    Toxic  Toxic
# frog_subcutaneous_LDLo                                      Toxic  Toxic
# mouse_intramuscular_LD50                                    Toxic  Toxic
# rat_intramuscular_LD50                                      Toxic  Toxic
# mouse_parenteral_LD50                                       Toxic  Toxic
#
#                                                     5               6     \
# mouse_intraperitoneal_LD50                         Toxic  Safe_chemicals
# mammal (species unspecified)_intraperitoneal_LD50  Toxic           Toxic
# guinea pig_intraperitoneal_LD50                    Toxic  Safe_chemicals
# rat_intraperitoneal_LD50                           Toxic  Safe_chemicals
# rabbit_intraperitoneal_LD50                        Toxic  Safe_chemicals
# mouse_intraperitoneal_LDLo                         Toxic           Toxic
# rat_intraperitoneal_LDLo                           Toxic           Toxic
# mouse_intravenous_LD50                             Toxic  Safe_chemicals
# guinea pig_intravenous_LD50                        Toxic  Safe_chemicals
# rat_intravenous_LD50                               Toxic  Safe_chemicals
# rabbit_intravenous_LD50                            Toxic  Safe_chemicals
# dog_intravenous_LD50                               Toxic  Safe_chemicals
# cat_intravenous_LD50                               Toxic  Safe_chemicals
# mouse_intravenous_LDLo                             Toxic  Safe_chemicals
# guinea pig_intravenous_LDLo                        Toxic  Safe_chemicals
# rat_intravenous_LDLo                               Toxic           Toxic
# rabbit_intravenous_LDLo                            Toxic  Safe_chemicals
# dog_intravenous_LDLo                               Toxic  Safe_chemicals
# cat_intravenous_LDLo                               Toxic  Safe_chemicals
# mouse_oral_LD50                                    Toxic           Toxic
# mammal (species unspecified)_oral_LD50             Toxic           Toxic
# guinea pig_oral_LD50                               Toxic           Toxic
# rat_oral_LD50                                      Toxic           Toxic
# rabbit_oral_LD50                                   Toxic           Toxic
# dog_oral_LD50                                      Toxic           Toxic
# cat_oral_LD50                                      Toxic           Toxic
# bird - wild_oral_LD50                              Toxic  Safe_chemicals
# quail_oral_LD50                                    Toxic           Toxic
# duck_oral_LD50                                     Toxic           Toxic
# chicken_oral_LD50                                  Toxic           Toxic
# mouse_oral_LDLo                                    Toxic           Toxic
# rat_oral_LDLo                                      Toxic           Toxic
# rabbit_oral_LDLo                                   Toxic           Toxic
# dog_oral_LDLo                                      Toxic           Toxic
# cat_oral_LDLo                                      Toxic  Safe_chemicals
# man_oral_TDLo                                      Toxic  Safe_chemicals
# women_oral_TDLo                                    Toxic           Toxic
# human_oral_TDLo                                    Toxic  Safe_chemicals
# mouse_unreported_LD50                              Toxic  Safe_chemicals
# mammal (species unspecified)_unreported_LD50       Toxic           Toxic
# rat_unreported_LD50                                Toxic           Toxic
# mouse_skin_LD50                                    Toxic  Safe_chemicals
# guinea pig_skin_LD50                               Toxic           Toxic
# rat_skin_LD50                                      Toxic           Toxic
# rabbit_skin_LD50                                   Toxic           Toxic
# rabbit_skin_LDLo                                   Toxic           Toxic
# mouse_subcutaneous_LD50                            Toxic  Safe_chemicals
# mammal (species unspecified)_subcutaneous_LD50     Toxic  Safe_chemicals
# guinea pig_subcutaneous_LD50                       Toxic  Safe_chemicals
# rat_subcutaneous_LD50                              Toxic  Safe_chemicals
# rabbit_subcutaneous_LD50                           Toxic  Safe_chemicals
# mouse_subcutaneous_LDLo                            Toxic  Safe_chemicals
# guinea pig_subcutaneous_LDLo                       Toxic  Safe_chemicals
# rat_subcutaneous_LDLo                              Toxic  Safe_chemicals
# rabbit_subcutaneous_LDLo                           Toxic  Safe_chemicals
# frog_subcutaneous_LDLo                             Toxic           Toxic
# mouse_intramuscular_LD50                           Toxic  Safe_chemicals
# rat_intramuscular_LD50                             Toxic           Toxic
# mouse_parenteral_LD50                              Toxic  Safe_chemicals
#
#                                                     7               8     \
# mouse_intraperitoneal_LD50                         Toxic           Toxic
# mammal (species unspecified)_intraperitoneal_LD50  Toxic           Toxic
# guinea pig_intraperitoneal_LD50                    Toxic           Toxic
# rat_intraperitoneal_LD50                           Toxic           Toxic
# rabbit_intraperitoneal_LD50                        Toxic           Toxic
# mouse_intraperitoneal_LDLo                         Toxic           Toxic
# rat_intraperitoneal_LDLo                           Toxic           Toxic
# mouse_intravenous_LD50                             Toxic           Toxic
# guinea pig_intravenous_LD50                        Toxic           Toxic
# rat_intravenous_LD50                               Toxic           Toxic
# rabbit_intravenous_LD50                            Toxic           Toxic
# dog_intravenous_LD50                               Toxic           Toxic
# cat_intravenous_LD50                               Toxic           Toxic
# mouse_intravenous_LDLo                             Toxic           Toxic
# guinea pig_intravenous_LDLo                        Toxic           Toxic
# rat_intravenous_LDLo                               Toxic           Toxic
# rabbit_intravenous_LDLo                            Toxic           Toxic
# dog_intravenous_LDLo                               Toxic           Toxic
# cat_intravenous_LDLo                               Toxic           Toxic
# mouse_oral_LD50                                    Toxic           Toxic
# mammal (species unspecified)_oral_LD50             Toxic           Toxic
# guinea pig_oral_LD50                               Toxic           Toxic
# rat_oral_LD50                                      Toxic           Toxic
# rabbit_oral_LD50                                   Toxic           Toxic
# dog_oral_LD50                                      Toxic           Toxic
# cat_oral_LD50                                      Toxic           Toxic
# bird - wild_oral_LD50                              Toxic           Toxic
# quail_oral_LD50                                    Toxic           Toxic
# duck_oral_LD50                                     Toxic           Toxic
# chicken_oral_LD50                                  Toxic           Toxic
# mouse_oral_LDLo                                    Toxic           Toxic
# rat_oral_LDLo                                      Toxic           Toxic
# rabbit_oral_LDLo                                   Toxic           Toxic
# dog_oral_LDLo                                      Toxic           Toxic
# cat_oral_LDLo                                      Toxic           Toxic
# man_oral_TDLo                                      Toxic  Safe_chemicals
# women_oral_TDLo                                    Toxic           Toxic
# human_oral_TDLo                                    Toxic  Safe_chemicals
# mouse_unreported_LD50                              Toxic           Toxic
# mammal (species unspecified)_unreported_LD50       Toxic           Toxic
# rat_unreported_LD50                                Toxic           Toxic
# mouse_skin_LD50                                    Toxic           Toxic
# guinea pig_skin_LD50                               Toxic           Toxic
# rat_skin_LD50                                      Toxic           Toxic
# rabbit_skin_LD50                                   Toxic           Toxic
# rabbit_skin_LDLo                                   Toxic           Toxic
# mouse_subcutaneous_LD50                            Toxic           Toxic
# mammal (species unspecified)_subcutaneous_LD50     Toxic           Toxic
# guinea pig_subcutaneous_LD50                       Toxic           Toxic
# rat_subcutaneous_LD50                              Toxic           Toxic
# rabbit_subcutaneous_LD50                           Toxic           Toxic
# mouse_subcutaneous_LDLo                            Toxic           Toxic
# guinea pig_subcutaneous_LDLo                       Toxic           Toxic
# rat_subcutaneous_LDLo                              Toxic           Toxic
# rabbit_subcutaneous_LDLo                           Toxic           Toxic
# frog_subcutaneous_LDLo                             Toxic           Toxic
# mouse_intramuscular_LD50                           Toxic           Toxic
# rat_intramuscular_LD50                             Toxic           Toxic
# mouse_parenteral_LD50                              Toxic           Toxic
#
#                                                              9     ...  \
# mouse_intraperitoneal_LD50                                  Toxic  ...
# mammal (species unspecified)_intraperitoneal_LD50           Toxic  ...
# guinea pig_intraperitoneal_LD50                             Toxic  ...
# rat_intraperitoneal_LD50                                    Toxic  ...
# rabbit_intraperitoneal_LD50                                 Toxic  ...
# mouse_intraperitoneal_LDLo                                  Toxic  ...
# rat_intraperitoneal_LDLo                                    Toxic  ...
# mouse_intravenous_LD50                                      Toxic  ...
# guinea pig_intravenous_LD50                                 Toxic  ...
# rat_intravenous_LD50                                        Toxic  ...
# rabbit_intravenous_LD50                                     Toxic  ...
# dog_intravenous_LD50                                        Toxic  ...
# cat_intravenous_LD50                                        Toxic  ...
# mouse_intravenous_LDLo                                      Toxic  ...
# guinea pig_intravenous_LDLo                                 Toxic  ...
# rat_intravenous_LDLo                                        Toxic  ...
# rabbit_intravenous_LDLo                                     Toxic  ...
# dog_intravenous_LDLo                                        Toxic  ...
# cat_intravenous_LDLo                                        Toxic  ...
# mouse_oral_LD50                                             Toxic  ...
# mammal (species unspecified)_oral_LD50                      Toxic  ...
# guinea pig_oral_LD50                                        Toxic  ...
# rat_oral_LD50                                               Toxic  ...
# rabbit_oral_LD50                                            Toxic  ...
# dog_oral_LD50                                               Toxic  ...
# cat_oral_LD50                                               Toxic  ...
# bird - wild_oral_LD50                                       Toxic  ...
# quail_oral_LD50                                             Toxic  ...
# duck_oral_LD50                                              Toxic  ...
# chicken_oral_LD50                                           Toxic  ...
# mouse_oral_LDLo                                             Toxic  ...
# rat_oral_LDLo                                               Toxic  ...
# rabbit_oral_LDLo                                            Toxic  ...
# dog_oral_LDLo                                               Toxic  ...
# cat_oral_LDLo                                               Toxic  ...
# man_oral_TDLo                                      Safe_chemicals  ...
# women_oral_TDLo                                             Toxic  ...
# human_oral_TDLo                                             Toxic  ...
# mouse_unreported_LD50                                       Toxic  ...
# mammal (species unspecified)_unreported_LD50                Toxic  ...
# rat_unreported_LD50                                         Toxic  ...
# mouse_skin_LD50                                             Toxic  ...
# guinea pig_skin_LD50                                        Toxic  ...
# rat_skin_LD50                                               Toxic  ...
# rabbit_skin_LD50                                            Toxic  ...
# rabbit_skin_LDLo                                            Toxic  ...
# mouse_subcutaneous_LD50                                     Toxic  ...
# mammal (species unspecified)_subcutaneous_LD50              Toxic  ...
# guinea pig_subcutaneous_LD50                                Toxic  ...
# rat_subcutaneous_LD50                                       Toxic  ...
# rabbit_subcutaneous_LD50                                    Toxic  ...
# mouse_subcutaneous_LDLo                                     Toxic  ...
# guinea pig_subcutaneous_LDLo                                Toxic  ...
# rat_subcutaneous_LDLo                                       Toxic  ...
# rabbit_subcutaneous_LDLo                                    Toxic  ...
# frog_subcutaneous_LDLo                                      Toxic  ...
# mouse_intramuscular_LD50                                    Toxic  ...
# rat_intramuscular_LD50                                      Toxic  ...
# mouse_parenteral_LD50                                       Toxic  ...
#
#                                                              1367  \
# mouse_intraperitoneal_LD50                                  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic
# guinea pig_intraperitoneal_LD50                             Toxic
# rat_intraperitoneal_LD50                                    Toxic
# rabbit_intraperitoneal_LD50                                 Toxic
# mouse_intraperitoneal_LDLo                                  Toxic
# rat_intraperitoneal_LDLo                                    Toxic
# mouse_intravenous_LD50                                      Toxic
# guinea pig_intravenous_LD50                                 Toxic
# rat_intravenous_LD50                                        Toxic
# rabbit_intravenous_LD50                                     Toxic
# dog_intravenous_LD50                                        Toxic
# cat_intravenous_LD50                                        Toxic
# mouse_intravenous_LDLo                                      Toxic
# guinea pig_intravenous_LDLo                                 Toxic
# rat_intravenous_LDLo                                        Toxic
# rabbit_intravenous_LDLo                                     Toxic
# dog_intravenous_LDLo                                        Toxic
# cat_intravenous_LDLo                                        Toxic
# mouse_oral_LD50                                             Toxic
# mammal (species unspecified)_oral_LD50                      Toxic
# guinea pig_oral_LD50                                        Toxic
# rat_oral_LD50                                               Toxic
# rabbit_oral_LD50                                            Toxic
# dog_oral_LD50                                               Toxic
# cat_oral_LD50                                               Toxic
# bird - wild_oral_LD50                                       Toxic
# quail_oral_LD50                                             Toxic
# duck_oral_LD50                                              Toxic
# chicken_oral_LD50                                           Toxic
# mouse_oral_LDLo                                             Toxic
# rat_oral_LDLo                                               Toxic
# rabbit_oral_LDLo                                            Toxic
# dog_oral_LDLo                                               Toxic
# cat_oral_LDLo                                               Toxic
# man_oral_TDLo                                               Toxic
# women_oral_TDLo                                             Toxic
# human_oral_TDLo                                    Safe_chemicals
# mouse_unreported_LD50                                       Toxic
# mammal (species unspecified)_unreported_LD50                Toxic
# rat_unreported_LD50                                         Toxic
# mouse_skin_LD50                                             Toxic
# guinea pig_skin_LD50                                        Toxic
# rat_skin_LD50                                               Toxic
# rabbit_skin_LD50                                            Toxic
# rabbit_skin_LDLo                                            Toxic
# mouse_subcutaneous_LD50                                     Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic
# guinea pig_subcutaneous_LD50                                Toxic
# rat_subcutaneous_LD50                                       Toxic
# rabbit_subcutaneous_LD50                                    Toxic
# mouse_subcutaneous_LDLo                                     Toxic
# guinea pig_subcutaneous_LDLo                                Toxic
# rat_subcutaneous_LDLo                                       Toxic
# rabbit_subcutaneous_LDLo                                    Toxic
# frog_subcutaneous_LDLo                                      Toxic
# mouse_intramuscular_LD50                                    Toxic
# rat_intramuscular_LD50                                      Toxic
# mouse_parenteral_LD50                                       Toxic
#
#                                                              1368   1369  \
# mouse_intraperitoneal_LD50                                  Toxic  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic  Toxic
# guinea pig_intraperitoneal_LD50                             Toxic  Toxic
# rat_intraperitoneal_LD50                                    Toxic  Toxic
# rabbit_intraperitoneal_LD50                                 Toxic  Toxic
# mouse_intraperitoneal_LDLo                                  Toxic  Toxic
# rat_intraperitoneal_LDLo                                    Toxic  Toxic
# mouse_intravenous_LD50                                      Toxic  Toxic
# guinea pig_intravenous_LD50                                 Toxic  Toxic
# rat_intravenous_LD50                                        Toxic  Toxic
# rabbit_intravenous_LD50                                     Toxic  Toxic
# dog_intravenous_LD50                                        Toxic  Toxic
# cat_intravenous_LD50                                        Toxic  Toxic
# mouse_intravenous_LDLo                                      Toxic  Toxic
# guinea pig_intravenous_LDLo                                 Toxic  Toxic
# rat_intravenous_LDLo                                        Toxic  Toxic
# rabbit_intravenous_LDLo                                     Toxic  Toxic
# dog_intravenous_LDLo                                        Toxic  Toxic
# cat_intravenous_LDLo                                        Toxic  Toxic
# mouse_oral_LD50                                             Toxic  Toxic
# mammal (species unspecified)_oral_LD50                      Toxic  Toxic
# guinea pig_oral_LD50                                        Toxic  Toxic
# rat_oral_LD50                                               Toxic  Toxic
# rabbit_oral_LD50                                            Toxic  Toxic
# dog_oral_LD50                                               Toxic  Toxic
# cat_oral_LD50                                               Toxic  Toxic
# bird - wild_oral_LD50                                       Toxic  Toxic
# quail_oral_LD50                                             Toxic  Toxic
# duck_oral_LD50                                              Toxic  Toxic
# chicken_oral_LD50                                           Toxic  Toxic
# mouse_oral_LDLo                                             Toxic  Toxic
# rat_oral_LDLo                                               Toxic  Toxic
# rabbit_oral_LDLo                                            Toxic  Toxic
# dog_oral_LDLo                                               Toxic  Toxic
# cat_oral_LDLo                                               Toxic  Toxic
# man_oral_TDLo                                      Safe_chemicals  Toxic
# women_oral_TDLo                                    Safe_chemicals  Toxic
# human_oral_TDLo                                    Safe_chemicals  Toxic
# mouse_unreported_LD50                                       Toxic  Toxic
# mammal (species unspecified)_unreported_LD50                Toxic  Toxic
# rat_unreported_LD50                                         Toxic  Toxic
# mouse_skin_LD50                                             Toxic  Toxic
# guinea pig_skin_LD50                                        Toxic  Toxic
# rat_skin_LD50                                               Toxic  Toxic
# rabbit_skin_LD50                                            Toxic  Toxic
# rabbit_skin_LDLo                                            Toxic  Toxic
# mouse_subcutaneous_LD50                                     Toxic  Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic  Toxic
# guinea pig_subcutaneous_LD50                                Toxic  Toxic
# rat_subcutaneous_LD50                                       Toxic  Toxic
# rabbit_subcutaneous_LD50                                    Toxic  Toxic
# mouse_subcutaneous_LDLo                                     Toxic  Toxic
# guinea pig_subcutaneous_LDLo                                Toxic  Toxic
# rat_subcutaneous_LDLo                                       Toxic  Toxic
# rabbit_subcutaneous_LDLo                                    Toxic  Toxic
# frog_subcutaneous_LDLo                                      Toxic  Toxic
# mouse_intramuscular_LD50                                    Toxic  Toxic
# rat_intramuscular_LD50                                      Toxic  Toxic
# mouse_parenteral_LD50                                       Toxic  Toxic
#
#                                                     1370   1371  \
# mouse_intraperitoneal_LD50                         Toxic  Toxic
# mammal (species unspecified)_intraperitoneal_LD50  Toxic  Toxic
# guinea pig_intraperitoneal_LD50                    Toxic  Toxic
# rat_intraperitoneal_LD50                           Toxic  Toxic
# rabbit_intraperitoneal_LD50                        Toxic  Toxic
# mouse_intraperitoneal_LDLo                         Toxic  Toxic
# rat_intraperitoneal_LDLo                           Toxic  Toxic
# mouse_intravenous_LD50                             Toxic  Toxic
# guinea pig_intravenous_LD50                        Toxic  Toxic
# rat_intravenous_LD50                               Toxic  Toxic
# rabbit_intravenous_LD50                            Toxic  Toxic
# dog_intravenous_LD50                               Toxic  Toxic
# cat_intravenous_LD50                               Toxic  Toxic
# mouse_intravenous_LDLo                             Toxic  Toxic
# guinea pig_intravenous_LDLo                        Toxic  Toxic
# rat_intravenous_LDLo                               Toxic  Toxic
# rabbit_intravenous_LDLo                            Toxic  Toxic
# dog_intravenous_LDLo                               Toxic  Toxic
# cat_intravenous_LDLo                               Toxic  Toxic
# mouse_oral_LD50                                    Toxic  Toxic
# mammal (species unspecified)_oral_LD50             Toxic  Toxic
# guinea pig_oral_LD50                               Toxic  Toxic
# rat_oral_LD50                                      Toxic  Toxic
# rabbit_oral_LD50                                   Toxic  Toxic
# dog_oral_LD50                                      Toxic  Toxic
# cat_oral_LD50                                      Toxic  Toxic
# bird - wild_oral_LD50                              Toxic  Toxic
# quail_oral_LD50                                    Toxic  Toxic
# duck_oral_LD50                                     Toxic  Toxic
# chicken_oral_LD50                                  Toxic  Toxic
# mouse_oral_LDLo                                    Toxic  Toxic
# rat_oral_LDLo                                      Toxic  Toxic
# rabbit_oral_LDLo                                   Toxic  Toxic
# dog_oral_LDLo                                      Toxic  Toxic
# cat_oral_LDLo                                      Toxic  Toxic
# man_oral_TDLo                                      Toxic  Toxic
# women_oral_TDLo                                    Toxic  Toxic
# human_oral_TDLo                                    Toxic  Toxic
# mouse_unreported_LD50                              Toxic  Toxic
# mammal (species unspecified)_unreported_LD50       Toxic  Toxic
# rat_unreported_LD50                                Toxic  Toxic
# mouse_skin_LD50                                    Toxic  Toxic
# guinea pig_skin_LD50                               Toxic  Toxic
# rat_skin_LD50                                      Toxic  Toxic
# rabbit_skin_LD50                                   Toxic  Toxic
# rabbit_skin_LDLo                                   Toxic  Toxic
# mouse_subcutaneous_LD50                            Toxic  Toxic
# mammal (species unspecified)_subcutaneous_LD50     Toxic  Toxic
# guinea pig_subcutaneous_LD50                       Toxic  Toxic
# rat_subcutaneous_LD50                              Toxic  Toxic
# rabbit_subcutaneous_LD50                           Toxic  Toxic
# mouse_subcutaneous_LDLo                            Toxic  Toxic
# guinea pig_subcutaneous_LDLo                       Toxic  Toxic
# rat_subcutaneous_LDLo                              Toxic  Toxic
# rabbit_subcutaneous_LDLo                           Toxic  Toxic
# frog_subcutaneous_LDLo                             Toxic  Toxic
# mouse_intramuscular_LD50                           Toxic  Toxic
# rat_intramuscular_LD50                             Toxic  Toxic
# mouse_parenteral_LD50                              Toxic  Toxic
#
#                                                              1372  \
# mouse_intraperitoneal_LD50                                  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic
# guinea pig_intraperitoneal_LD50                             Toxic
# rat_intraperitoneal_LD50                                    Toxic
# rabbit_intraperitoneal_LD50                                 Toxic
# mouse_intraperitoneal_LDLo                                  Toxic
# rat_intraperitoneal_LDLo                                    Toxic
# mouse_intravenous_LD50                                      Toxic
# guinea pig_intravenous_LD50                                 Toxic
# rat_intravenous_LD50                                        Toxic
# rabbit_intravenous_LD50                                     Toxic
# dog_intravenous_LD50                                        Toxic
# cat_intravenous_LD50                                        Toxic
# mouse_intravenous_LDLo                                      Toxic
# guinea pig_intravenous_LDLo                                 Toxic
# rat_intravenous_LDLo                                        Toxic
# rabbit_intravenous_LDLo                                     Toxic
# dog_intravenous_LDLo                                        Toxic
# cat_intravenous_LDLo                                        Toxic
# mouse_oral_LD50                                             Toxic
# mammal (species unspecified)_oral_LD50                      Toxic
# guinea pig_oral_LD50                                        Toxic
# rat_oral_LD50                                               Toxic
# rabbit_oral_LD50                                            Toxic
# dog_oral_LD50                                               Toxic
# cat_oral_LD50                                               Toxic
# bird - wild_oral_LD50                                       Toxic
# quail_oral_LD50                                             Toxic
# duck_oral_LD50                                              Toxic
# chicken_oral_LD50                                           Toxic
# mouse_oral_LDLo                                             Toxic
# rat_oral_LDLo                                               Toxic
# rabbit_oral_LDLo                                            Toxic
# dog_oral_LDLo                                               Toxic
# cat_oral_LDLo                                               Toxic
# man_oral_TDLo                                      Safe_chemicals
# women_oral_TDLo                                    Safe_chemicals
# human_oral_TDLo                                    Safe_chemicals
# mouse_unreported_LD50                                       Toxic
# mammal (species unspecified)_unreported_LD50                Toxic
# rat_unreported_LD50                                         Toxic
# mouse_skin_LD50                                             Toxic
# guinea pig_skin_LD50                                        Toxic
# rat_skin_LD50                                               Toxic
# rabbit_skin_LD50                                            Toxic
# rabbit_skin_LDLo                                            Toxic
# mouse_subcutaneous_LD50                                     Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic
# guinea pig_subcutaneous_LD50                                Toxic
# rat_subcutaneous_LD50                                       Toxic
# rabbit_subcutaneous_LD50                                    Toxic
# mouse_subcutaneous_LDLo                                     Toxic
# guinea pig_subcutaneous_LDLo                                Toxic
# rat_subcutaneous_LDLo                                       Toxic
# rabbit_subcutaneous_LDLo                                    Toxic
# frog_subcutaneous_LDLo                                      Toxic
# mouse_intramuscular_LD50                                    Toxic
# rat_intramuscular_LD50                                      Toxic
# mouse_parenteral_LD50                                       Toxic
#
#                                                              1373   1374  \
# mouse_intraperitoneal_LD50                                  Toxic  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic  Toxic
# guinea pig_intraperitoneal_LD50                             Toxic  Toxic
# rat_intraperitoneal_LD50                                    Toxic  Toxic
# rabbit_intraperitoneal_LD50                                 Toxic  Toxic
# mouse_intraperitoneal_LDLo                                  Toxic  Toxic
# rat_intraperitoneal_LDLo                                    Toxic  Toxic
# mouse_intravenous_LD50                                      Toxic  Toxic
# guinea pig_intravenous_LD50                                 Toxic  Toxic
# rat_intravenous_LD50                                        Toxic  Toxic
# rabbit_intravenous_LD50                                     Toxic  Toxic
# dog_intravenous_LD50                                        Toxic  Toxic
# cat_intravenous_LD50                                        Toxic  Toxic
# mouse_intravenous_LDLo                                      Toxic  Toxic
# guinea pig_intravenous_LDLo                                 Toxic  Toxic
# rat_intravenous_LDLo                                        Toxic  Toxic
# rabbit_intravenous_LDLo                                     Toxic  Toxic
# dog_intravenous_LDLo                                        Toxic  Toxic
# cat_intravenous_LDLo                                        Toxic  Toxic
# mouse_oral_LD50                                             Toxic  Toxic
# mammal (species unspecified)_oral_LD50                      Toxic  Toxic
# guinea pig_oral_LD50                                        Toxic  Toxic
# rat_oral_LD50                                               Toxic  Toxic
# rabbit_oral_LD50                                            Toxic  Toxic
# dog_oral_LD50                                               Toxic  Toxic
# cat_oral_LD50                                               Toxic  Toxic
# bird - wild_oral_LD50                                       Toxic  Toxic
# quail_oral_LD50                                             Toxic  Toxic
# duck_oral_LD50                                              Toxic  Toxic
# chicken_oral_LD50                                           Toxic  Toxic
# mouse_oral_LDLo                                             Toxic  Toxic
# rat_oral_LDLo                                               Toxic  Toxic
# rabbit_oral_LDLo                                            Toxic  Toxic
# dog_oral_LDLo                                               Toxic  Toxic
# cat_oral_LDLo                                               Toxic  Toxic
# man_oral_TDLo                                      Safe_chemicals  Toxic
# women_oral_TDLo                                    Safe_chemicals  Toxic
# human_oral_TDLo                                    Safe_chemicals  Toxic
# mouse_unreported_LD50                                       Toxic  Toxic
# mammal (species unspecified)_unreported_LD50                Toxic  Toxic
# rat_unreported_LD50                                         Toxic  Toxic
# mouse_skin_LD50                                             Toxic  Toxic
# guinea pig_skin_LD50                                        Toxic  Toxic
# rat_skin_LD50                                               Toxic  Toxic
# rabbit_skin_LD50                                            Toxic  Toxic
# rabbit_skin_LDLo                                            Toxic  Toxic
# mouse_subcutaneous_LD50                                     Toxic  Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic  Toxic
# guinea pig_subcutaneous_LD50                                Toxic  Toxic
# rat_subcutaneous_LD50                                       Toxic  Toxic
# rabbit_subcutaneous_LD50                                    Toxic  Toxic
# mouse_subcutaneous_LDLo                                     Toxic  Toxic
# guinea pig_subcutaneous_LDLo                                Toxic  Toxic
# rat_subcutaneous_LDLo                                       Toxic  Toxic
# rabbit_subcutaneous_LDLo                                    Toxic  Toxic
# frog_subcutaneous_LDLo                                      Toxic  Toxic
# mouse_intramuscular_LD50                                    Toxic  Toxic
# rat_intramuscular_LD50                                      Toxic  Toxic
# mouse_parenteral_LD50                                       Toxic  Toxic
#
#                                                              1375   1376
# mouse_intraperitoneal_LD50                                  Toxic  Toxic
# mammal (species unspecified)_intraperitoneal_LD50           Toxic  Toxic
# guinea pig_intraperitoneal_LD50                             Toxic  Toxic
# rat_intraperitoneal_LD50                                    Toxic  Toxic
# rabbit_intraperitoneal_LD50                                 Toxic  Toxic
# mouse_intraperitoneal_LDLo                                  Toxic  Toxic
# rat_intraperitoneal_LDLo                                    Toxic  Toxic
# mouse_intravenous_LD50                                      Toxic  Toxic
# guinea pig_intravenous_LD50                                 Toxic  Toxic
# rat_intravenous_LD50                                        Toxic  Toxic
# rabbit_intravenous_LD50                                     Toxic  Toxic
# dog_intravenous_LD50                                        Toxic  Toxic
# cat_intravenous_LD50                                        Toxic  Toxic
# mouse_intravenous_LDLo                                      Toxic  Toxic
# guinea pig_intravenous_LDLo                                 Toxic  Toxic
# rat_intravenous_LDLo                                        Toxic  Toxic
# rabbit_intravenous_LDLo                                     Toxic  Toxic
# dog_intravenous_LDLo                                        Toxic  Toxic
# cat_intravenous_LDLo                                        Toxic  Toxic
# mouse_oral_LD50                                             Toxic  Toxic
# mammal (species unspecified)_oral_LD50                      Toxic  Toxic
# guinea pig_oral_LD50                                        Toxic  Toxic
# rat_oral_LD50                                               Toxic  Toxic
# rabbit_oral_LD50                                            Toxic  Toxic
# dog_oral_LD50                                               Toxic  Toxic
# cat_oral_LD50                                               Toxic  Toxic
# bird - wild_oral_LD50                                       Toxic  Toxic
# quail_oral_LD50                                             Toxic  Toxic
# duck_oral_LD50                                              Toxic  Toxic
# chicken_oral_LD50                                           Toxic  Toxic
# mouse_oral_LDLo                                             Toxic  Toxic
# rat_oral_LDLo                                               Toxic  Toxic
# rabbit_oral_LDLo                                            Toxic  Toxic
# dog_oral_LDLo                                               Toxic  Toxic
# cat_oral_LDLo                                               Toxic  Toxic
# man_oral_TDLo                                      Safe_chemicals  Toxic
# women_oral_TDLo                                    Safe_chemicals  Toxic
# human_oral_TDLo                                             Toxic  Toxic
# mouse_unreported_LD50                                       Toxic  Toxic
# mammal (species unspecified)_unreported_LD50                Toxic  Toxic
# rat_unreported_LD50                                         Toxic  Toxic
# mouse_skin_LD50                                             Toxic  Toxic
# guinea pig_skin_LD50                                        Toxic  Toxic
# rat_skin_LD50                                               Toxic  Toxic
# rabbit_skin_LD50                                            Toxic  Toxic
# rabbit_skin_LDLo                                            Toxic  Toxic
# mouse_subcutaneous_LD50                                     Toxic  Toxic
# mammal (species unspecified)_subcutaneous_LD50              Toxic  Toxic
# guinea pig_subcutaneous_LD50                                Toxic  Toxic
# rat_subcutaneous_LD50                                       Toxic  Toxic
# rabbit_subcutaneous_LD50                                    Toxic  Toxic
# mouse_subcutaneous_LDLo                                     Toxic  Toxic
# guinea pig_subcutaneous_LDLo                                Toxic  Toxic
# rat_subcutaneous_LDLo                                       Toxic  Toxic
# rabbit_subcutaneous_LDLo                                    Toxic  Toxic
# frog_subcutaneous_LDLo                                      Toxic  Toxic
# mouse_intramuscular_LD50                                    Toxic  Toxic
# rat_intramuscular_LD50                                      Toxic  Toxic
# mouse_parenteral_LD50                                       Toxic  Toxic
#
# [59 rows x 1377 columns]

# %%
print('Make result file format')
task_list = np.load(data_path + "task_list.npy")
pred = pd.DataFrame(y_pred)
pred.columns = task_list
pred['molwt'] = data['MolWt'].values

for i in range(len(pred)):
    reverse_standardization = (1/10**(pred.iloc[i,0:59]))*pred.iloc[i,59]*10**(3)
    pred.iloc[i,0:59] = reverse_standardization
# Out:
# Make result file format

# %%
pred_label = pred.iloc[:,0:-1]
pred_label = pred_label.applymap(toxic_label2)

# %%
pred_label
# Out:
#      mouse_intraperitoneal_LD50  \
# 0                         Toxic
# 1                         Toxic
# 2                         Toxic
# 3                         Toxic
# 4                         Toxic
# ...                         ...
# 1372                      Toxic
# 1373                      Toxic
# 1374                      Toxic
# 1375                      Toxic
# 1376                      Toxic
#
#      mammal (species unspecified)_intraperitoneal_LD50  \
# 0                                                Toxic
# 1                                                Toxic
# 2                                                Toxic
# 3                                                Toxic
# 4                                                Toxic
# ...                                                ...
# 1372                                             Toxic
# 1373                                             Toxic
# 1374                                             Toxic
# 1375                                             Toxic
# 1376                                             Toxic
#
#      guinea pig_intraperitoneal_LD50 rat_intraperitoneal_LD50  \
# 0                              Toxic                    Toxic
# 1                              Toxic                    Toxic
# 2                              Toxic                    Toxic
# 3                              Toxic                    Toxic
# 4                              Toxic                    Toxic
# ...                              ...                      ...
# 1372                           Toxic                    Toxic
# 1373                           Toxic                    Toxic
# 1374                           Toxic                    Toxic
# 1375                           Toxic                    Toxic
# 1376                           Toxic                    Toxic
#
#      rabbit_intraperitoneal_LD50 mouse_intraperitoneal_LDLo  \
# 0                          Toxic                      Toxic
# 1                          Toxic                      Toxic
# 2                          Toxic                      Toxic
# 3                          Toxic                      Toxic
# 4                          Toxic                      Toxic
# ...                          ...                        ...
# 1372                       Toxic                      Toxic
# 1373                       Toxic                      Toxic
# 1374                       Toxic                      Toxic
# 1375                       Toxic                      Toxic
# 1376                       Toxic                      Toxic
#
#      rat_intraperitoneal_LDLo mouse_intravenous_LD50  \
# 0                       Toxic                  Toxic
# 1                       Toxic                  Toxic
# 2                       Toxic                  Toxic
# 3                       Toxic                  Toxic
# 4                       Toxic                  Toxic
# ...                       ...                    ...
# 1372                    Toxic                  Toxic
# 1373                    Toxic                  Toxic
# 1374                    Toxic                  Toxic
# 1375                    Toxic                  Toxic
# 1376                    Toxic                  Toxic
#
#      guinea pig_intravenous_LD50 rat_intravenous_LD50  ...  \
# 0                          Toxic                Toxic  ...
# 1                 Safe_chemicals       Safe_chemicals  ...
# 2                          Toxic                Toxic  ...
# 3                          Toxic                Toxic  ...
# 4                          Toxic                Toxic  ...
# ...                          ...                  ...  ...
# 1372                       Toxic                Toxic  ...
# 1373                       Toxic                Toxic  ...
# 1374                       Toxic                Toxic  ...
# 1375                       Toxic                Toxic  ...
# 1376                       Toxic                Toxic  ...
#
#      rat_subcutaneous_LD50 rabbit_subcutaneous_LD50 mouse_subcutaneous_LDLo  \
# 0                    Toxic                    Toxic                   Toxic
# 1                    Toxic                    Toxic                   Toxic
# 2                    Toxic                    Toxic                   Toxic
# 3                    Toxic                    Toxic                   Toxic
# 4                    Toxic                    Toxic                   Toxic
# ...                    ...                      ...                     ...
# 1372                 Toxic                    Toxic                   Toxic
# 1373                 Toxic                    Toxic                   Toxic
# 1374                 Toxic                    Toxic                   Toxic
# 1375                 Toxic                    Toxic                   Toxic
# 1376                 Toxic                    Toxic                   Toxic
#
#      guinea pig_subcutaneous_LDLo rat_subcutaneous_LDLo  \
# 0                           Toxic                 Toxic
# 1                           Toxic                 Toxic
# 2                           Toxic                 Toxic
# 3                           Toxic                 Toxic
# 4                           Toxic                 Toxic
# ...                           ...                   ...
# 1372                        Toxic                 Toxic
# 1373                        Toxic                 Toxic
# 1374                        Toxic                 Toxic
# 1375                        Toxic                 Toxic
# 1376                        Toxic                 Toxic
#
#      rabbit_subcutaneous_LDLo frog_subcutaneous_LDLo mouse_intramuscular_LD50  \
# 0                       Toxic                  Toxic                    Toxic
# 1                       Toxic                  Toxic                    Toxic
# 2                       Toxic                  Toxic                    Toxic
# 3                       Toxic                  Toxic                    Toxic
# 4                       Toxic                  Toxic                    Toxic
# ...                       ...                    ...                      ...
# 1372                    Toxic                  Toxic                    Toxic
# 1373                    Toxic                  Toxic                    Toxic
# 1374                    Toxic                  Toxic                    Toxic
# 1375                    Toxic                  Toxic                    Toxic
# 1376                    Toxic                  Toxic                    Toxic
#
#      rat_intramuscular_LD50 mouse_parenteral_LD50
# 0                     Toxic                 Toxic
# 1                     Toxic                 Toxic
# 2                     Toxic                 Toxic
# 3                     Toxic                 Toxic
# 4                     Toxic                 Toxic
# ...                     ...                   ...
# 1372                  Toxic                 Toxic
# 1373                  Toxic                 Toxic
# 1374                  Toxic                 Toxic
# 1375                  Toxic                 Toxic
# 1376                  Toxic                 Toxic
#
# [1377 rows x 59 columns]
